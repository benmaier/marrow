# %% [markdown]
# # SVG Rendering Test
#
# Testing if Marrow renders SVG outputs correctly

# %%
from IPython.display import SVG, display

# Simple SVG graphic
svg_content = '''
<svg width="300" height="200" xmlns="http://www.w3.org/2000/svg">
  <rect x="10" y="10" width="280" height="180" fill="#f0f0f0" stroke="#333" stroke-width="2"/>
  <circle cx="80" cy="100" r="50" fill="#e74c3c"/>
  <circle cx="150" cy="100" r="50" fill="#3498db" opacity="0.7"/>
  <circle cx="220" cy="100" r="50" fill="#2ecc71" opacity="0.7"/>
  <text x="150" y="30" text-anchor="middle" font-size="16" fill="#333">SVG Test</text>
</svg>
'''

display(SVG(svg_content))
