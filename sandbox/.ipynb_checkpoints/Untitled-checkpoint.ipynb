# %%
import numpy as np
from tqdm import tqdm

# %%
d = dict(
    a = '1',
    b = 2
)

# %%
d['c']
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[6], line 1
# ----> 1 d['c']
#
# KeyError: 'c'

# %%
for i in tqdm(range(20)):
    print('x')
    if i == 4:
        d['4']
# Out:
#  20%|█████████████████▌                                                                      | 4/20 [00:00<00:00, 17367.72it/s]
# x
# x
# x
# x
# x
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[10], line 4
#       2 print('x')
#       3 if i == 4:
# ----> 4     d['4']
#
# KeyError: '4'
