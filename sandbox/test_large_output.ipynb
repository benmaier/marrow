# %% [markdown]
# # Test Large Output
#
# This notebook tests the output truncation feature.

# %%
# 400 lines - SHOULD be truncated (hidden = 190 > 80)
for i in range(400):
    print(f"Line {i}: ...")
# Out:
# Line 0: This is a test line with some content xxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxx
# Line 1: This is a test line with some content xxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxx
# Line 2: This is a test line with some content xxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxx
# Line 3: This is a test line with some content xxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxx
# Line 4: This is a test line with some content xxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxx
# Line 5: This is a test line with some content xxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxx
# Line 6: This is a test line with some content xxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxx
# Line 7: This is a test line with some content xxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxx
# Line 8: This is a test line with some content xxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxx
# Line 9: This is a test line with some content xxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxx
# Line 10: This is a test line with some content xxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxx
# Line 11: This is a test line with some content xxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxx
# ...

# %%
# 250 lines - should NOT be truncated (hidden = 40 < 80)
for i in range(250):
    print(f"Line {i}: ...")
# Out:
# Line 0: Medium output - should NOT be truncated
# Line 1: Medium output - should NOT be truncated
# Line 2: Medium output - should NOT be truncated
# Line 3: Medium output - should NOT be truncated
# Line 4: Medium output - should NOT be truncated
# Line 5: Medium output - should NOT be truncated
# Line 6: Medium output - should NOT be truncated
# Line 7: Medium output - should NOT be truncated
# Line 8: Medium output - should NOT be truncated
# Line 9: Medium output - should NOT be truncated
# Line 10: Medium output - should NOT be truncated
# Line 11: Medium output - should NOT be truncated
# Line 12: Medium output - should NOT be truncated
# Line 13: Medium output - should NOT be truncated
# Line 14: Medium output - should NOT be truncated
# Line 15: Medium output - should NOT be truncated
# Line 16: Medium output - should NOT be truncated
# Line 17: Medium output - should NOT be truncated
# Line 18: Medium output - should NOT be truncated
# ...

# %% [markdown]
# ## Small Output

# %%
print("Small output")
# Out:
# This is a small output.
# Just a few lines.
# No truncation needed.
