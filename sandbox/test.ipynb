# %% [markdown]
# # Test Notebook
#
# This is a **test notebook** to verify ipynb rendering.

# %%
import numpy as np

x = np.array([1, 2, 3])
print(x)
# Out:
# [1 2 3]

# %%
2 + 2
# Out:
# 4

# %% [markdown]
# ## Math Test
#
# Inline: $E = mc^2$
#
# Block:
# $$\int_0^\infty e^{-x^2} dx = \frac{\sqrt{\pi}}{2}$$
