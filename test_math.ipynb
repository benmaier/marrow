# %% [markdown]
# # Math Test
#
# Inline math: $E = mc^2$
#
# Display math:
# $$\int_0^\infty e^{-x^2} dx = \frac{\sqrt{\pi}}{2}$$
#
# More inline: The quadratic formula is $x = \frac{-b \pm \sqrt{b^2-4ac}}{2a}$

# %%
# This code has underscores and dollar signs
x1_Variable = 43.71
x2_Search = "4.98%"
price = "$9,116,143"
print(f"x1_Variable: {x1_Variable}")
print(f"x2_Search: {x2_Search} ($9,116,143)")
print(f"x3_Social: 8.13 $14,890,641")
print(f"Price_Discount: 0.44%")
print("This $should$ not render as math")
# Out:
# x1_Variable: 43.71
# x2_Search: 4.98% ($9,116,143)
# x3_Social: 8.13 $14,890,641
# Price_Discount: 0.44%
# This $should$ not render as math

# %% [markdown]
# ## Another markdown cell
#
# This should render math: $\alpha + \beta = \gamma$
